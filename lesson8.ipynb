# %% [markdown]
# ## Подключение библиотек и скриптов

# %%
import numpy as np
import pandas as pd
import random
from datetime import datetime

import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
matplotlib.rcParams.update({'font.size': 14})

import warnings
warnings.filterwarnings('ignore')

# %%
def sns_join(feature_1, feature_2):
    grid = sns.jointplot(feature_1, feature_2, kind='reg')
    grid.fig.set_figwidth(12)
    grid.fig.set_figheight(12)

    plt.show()

# %%
def reduce_mem_usage(df):

    start_mem = df.memory_usage().sum() / 1024**2
#    print('Memory usage of dataframe is {:.2f} MB'.format(start_mem))
    
    for col in df.columns:
        col_type = df[col].dtype
        
        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        else:
            df[col] = df[col].astype('category')

    end_mem = df.memory_usage().sum() / 1024**2
#    print('Memory usage after optimization is: {:.2f} MB'.format(end_mem))
#    print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) / start_mem))
    
    return df

# %%
class DataPipeline:
    
    def __init__(self):

        self.Rooms_Percent = None
        self.Kitchen_Percent = None
        self.Healthcare_Median = None 
       
    def fit(self, train_df):
        
        self.Rooms_Percent = (train_df['Rooms'] / train_df['Square']).mean() 
        self.Kitchen_Percent = (train_df['KitchenSquare'] / train_df['Square']).mean() 
        self.Healthcare_Median = train_df['Healthcare_1'].median()
            
    def transform(self, train_df):
        
        train_df = reduce_mem_usage(train_df)        
        train_df['Id'] = train_df['Id'].astype('category')
        train_df['DistrictId'] = train_df['DistrictId'].astype('category')
        
        train_df.loc[train_df['Rooms'] == 0, 'Rooms'] = np.nan
        train_df.loc[train_df['Rooms'] >  5, 'Rooms'] = np.nan
        
        train_df.loc[(train_df['Square'] > train_df['LifeSquare'] * 3) & (train_df['LifeSquare'] < 10), 'LifeSquare'] = np.nan        
        train_df.loc[(train_df['LifeSquare'] > train_df['Square'] * 2) & (train_df['Square'] < 10), 'Square'] = train_df['LifeSquare'] + train_df['KitchenSquare']        
        train_df.loc[(train_df['LifeSquare'] > train_df['Square'] * 2), 'LifeSquare'] = np.nan        
        train_df['Square'], train_df['LifeSquare'] = np.where(train_df['Square'] < train_df['LifeSquare'],(train_df['LifeSquare'],train_df['Square']), (train_df['Square'],train_df['LifeSquare']))        
        
        train_df.loc[train_df['Square'] < train_df['KitchenSquare'], 'KitchenSquare'] = np.nan        
        train_df.loc[train_df['Square'] * 0.5 < train_df['KitchenSquare'], 'KitchenSquare'] = np.nan
        
        train_df.loc[train_df['HouseFloor'] > 50, 'HouseFloor'] = train_df['Floor']
        train_df.loc[train_df['HouseFloor'] == 0, 'HouseFloor'] = train_df['Floor']        
        train_df['HouseFloor'], train_df['Floor'] = np.where(train_df['HouseFloor'] < train_df['Floor'],(train_df['Floor'],train_df['HouseFloor']), (train_df['HouseFloor'],train_df['Floor']))        
        
        train_df.loc[train_df['HouseYear'] > datetime.now().year, 'HouseYear'] = train_df['HouseYear'].median()
        
        train_df = pd.concat([train_df, pd.get_dummies(train_df['Ecology_2'])], axis=1)
        train_df.rename(columns={'A': 'Ecology_2_A', 'B': 'Ecology_2_B'}, inplace=True)
        train_df.drop('Ecology_2', axis=1, inplace=True)      
    
        train_df = pd.concat([train_df, pd.get_dummies(train_df['Ecology_3'])], axis=1)
        train_df.rename(columns={'A': 'Ecology_3_A', 'B': 'Ecology_3_B'}, inplace=True)
        train_df.drop('Ecology_3', axis=1, inplace=True)    
    
        train_df = pd.concat([train_df, pd.get_dummies(train_df['Shops_2'])], axis=1)
        train_df.rename(columns={'A': 'Shops_2_A', 'B': 'Shops_2_B'}, inplace=True)
        train_df.drop('Shops_2', axis=1, inplace=True)    
    
        train_df.loc[train_df['Rooms'].isna(), 'Rooms'] = np.round(train_df['Square'] * self.Rooms_Percent)
        train_df.loc[train_df['Rooms'] == 0, 'Rooms'] = 1
        train_df.loc[train_df['Rooms'] >  5, 'Rooms'] = 5    
        
        train_df.loc[train_df['KitchenSquare'].isna(), 'KitchenSquare'] = np.round(train_df['Square'] * self.Kitchen_Percent)        
        
        train_df.loc[train_df['LifeSquare'].isna(), 'LifeSquare'] = train_df['Square'] - train_df['KitchenSquare']
        
        train_df.loc[train_df['Healthcare_1'].isna(), 'Healthcare_1'] = self.Healthcare_Median
     
        feature_names_for_stand = ['Rooms', 'Square', 'LifeSquare', 'KitchenSquare', 'Floor', 'HouseFloor','HouseYear', 'Ecology_1', 'Social_1', 'Social_2', 'Social_3', 'Healthcare_1', 'Helthcare_2', 'Shops_1']

        district_size = train_df['DistrictId'].value_counts().reset_index().rename(columns={'index':'DistrictId', 'DistrictId':'DistrictSize'})
        train_df = train_df.merge(district_size, on='DistrictId', how='left')        
        
        train_df['IsDistrictLarge'] = (train_df['DistrictSize'] > 100).astype(int)

        return train_df

# %% [markdown]
# ## Описание данных

# %% [markdown]
# - Id - идентификационный номер квартиры
# - DistrictId - идентификационный номер района
# - Rooms - количество комнат
# - Square - площадь
# - LifeSquare - жилая площадь
# - KitchenSquare - площадь кухни
# - Floor - этаж
# - HouseFloor - количество этажей в доме
# - HouseYear - год постройки дома
# - Ecology_1, Ecology_2, Ecology_3 - экологические показатели местности
# - Social_1, Social_2, Social_3 - социальные показатели местности
# - Healthcare_1, Helthcare_2 - показатели местности, связанные с охраной здоровья
# - Shops_1, Shops_2 - показатели, связанные с наличием магазинов, торговых центров
# - Price - цена квартиры

# %% [markdown]
# ## Загрузка данных

# %%
train_df = pd.read_csv('train.csv')
train_df = reduce_mem_usage(train_df)
train_df.head()
# Out:
#       Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 0  14038          35    2.0  47.981560   29.442751            6.0      7
# 1  15053          41    3.0  65.683640   40.049541            8.0      7
# 2   4765          53    2.0  44.947952   29.197611            0.0      8
# 3   5809          58    2.0  53.352982   52.731510            9.0      8
# 4  10783          99    1.0  39.649193   23.776169            7.0     11
#
#    HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  Social_2  \
# 0         9.0       1969   0.089040         B         B        33      7976
# 1         9.0       1978   0.000070         B         B        46     10309
# 2        12.0       1968   0.049637         B         B        34      7759
# 3        17.0       1977   0.437885         B         B        23      5735
# 4        12.0       1976   0.012339         B         B        35      5776
#
#    Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2          Price
# 0         5           NaN            0       11       B  184966.937500
# 1         1         240.0            1       16       B  300009.437500
# 2         0         229.0            1        3       B  220925.906250
# 3         3        1084.0            0        5       B  175616.234375
# 4         1        2078.0            2        4       B  150226.531250

# %%
train_df.shape[0]
# Out:
# 10000

# %% [markdown]
# ## Распределение целевой переменной

# %%
plt.figure(figsize = (16, 8))

plt.subplot(121)
train_df['Price'].hist(density=False, bins=20)
plt.ylabel('count')
plt.xlabel('Price')

plt.subplot(122)
sns.kdeplot(train_df['Price'], shade=True, legend=False)
plt.xlabel('Price')

plt.suptitle('Distribution of Price')
plt.show()

# %% [markdown]
# ## Анализ признаков

# %%
plt.figure(figsize=(15, 10))

sns.set(font_scale=1.4)

corr_matrix = train_df.corr()
corr_matrix = np.round(corr_matrix, 2)
corr_matrix[np.abs(corr_matrix) < 0.3] = 0

sns.heatmap(corr_matrix, annot=True, linewidths=.5, cmap='coolwarm')

plt.title('Correlation matrix')
plt.show()

# %%
sns_join(train_df['Price'], train_df['Square'])

# %% [markdown]
# ## Обработка данных

# %%
train_df.dtypes
# Out:
# Id                  int16
# DistrictId          int16
# Rooms             float32
# Square            float32
# LifeSquare        float32
# KitchenSquare     float32
# Floor               int16
# HouseFloor        float32
# HouseYear           int32
# Ecology_1         float32
# Ecology_2        category
# Ecology_3        category
# Social_1            int16
# Social_2            int16
# Social_3            int16
# Healthcare_1      float32
# Helthcare_2         int16
# Shops_1             int16
# Shops_2          category
# Price             float32
# dtype: object

# %% [markdown]
# Заменим нечисловые типы на категории

# %%
train_df['Id'] = train_df['Id'].astype('category')
train_df['DistrictId'] = train_df['DistrictId'].astype('category')

# %% [markdown]
# ### Числовые признаки

# %%
train_df.describe()
# Out:
#               Rooms        Square   LifeSquare  KitchenSquare         Floor  \
# count  10000.000000  10000.000000  7887.000000   10000.000000  10000.000000
# mean       1.890500     56.315712    37.199596       6.273300      8.526700
# std        0.839523     21.058718    86.241112      28.561113      5.241148
# min        0.000000      1.136859     0.370619       0.000000      1.000000
# 25%        1.000000     41.774879    22.769833       1.000000      4.000000
# 50%        2.000000     52.513309    32.781261       6.000000      7.000000
# 75%        2.000000     65.900627    45.128803       9.000000     12.000000
# max       19.000000    641.065186  7480.592285    2014.000000     42.000000
#
#          HouseFloor     HouseYear     Ecology_1      Social_1      Social_2  \
# count  10000.000000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean      12.609400  3.990166e+03      0.118858     24.687000   5352.157400
# std        6.776192  2.005003e+05      0.119026     17.532614   4006.799803
# min        0.000000  1.910000e+03      0.000000      0.000000    168.000000
# 25%        9.000000  1.974000e+03      0.017647      6.000000   1564.000000
# 50%       13.000000  1.977000e+03      0.075424     25.000000   5285.000000
# 75%       17.000000  2.001000e+03      0.195781     36.000000   7227.000000
# max      117.000000  2.005201e+07      0.521867     74.000000  19083.000000
#
#            Social_3  Healthcare_1   Helthcare_2       Shops_1          Price
# count  10000.000000   5202.000000  10000.000000  10000.000000   10000.000000
# mean       8.039200   1142.904419      1.319500      4.231300  214139.218750
# std       23.831875   1021.518982      1.493601      4.806341   92872.304688
# min        0.000000      0.000000      0.000000      0.000000   59174.777344
# 25%        0.000000    350.000000      0.000000      1.000000  153872.628906
# 50%        2.000000    900.000000      1.000000      3.000000  192269.648438
# 75%        5.000000   1548.000000      2.000000      6.000000  249135.460938
# max      141.000000   4849.000000      6.000000     23.000000  633233.437500

# %% [markdown]
# #### Число комнат

# %%
train_df['Rooms'].value_counts()
# Out:
# 2.0     3880
# 1.0     3705
# 3.0     2235
# 4.0      150
# 5.0       18
# 0.0        8
# 10.0       2
# 19.0       1
# 6.0        1
# Name: Rooms, dtype: int64

# %%
train_df[train_df['Rooms'] == 5]
# Out:
#          Id DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 1422   4282        195    5.0   95.617531   62.377052            7.0      7
# 1503   1243         86    5.0  108.057396   82.723824            8.0      3
# 1982   5548         86    5.0  275.645294  233.949310           26.0     12
# 3268   8901         34    5.0  121.577423  114.913841            1.0     25
# 3271   6358         27    5.0   42.003292         NaN            0.0      5
# 4431   7594         53    5.0   39.906082   39.394024            1.0      5
# 4487  13434         13    5.0  183.382278  100.985504           15.0      2
# 4762   4070         21    5.0  114.313751   88.492653            9.0      6
# 5361   2879         78    5.0  118.871948   69.023506           10.0     15
# 5466   3454          8    5.0  112.135521   79.795448           10.0      4
# 6623   3294        167    5.0  111.045799   81.940460            9.0      6
# 6988   8685         62    5.0  124.933289   81.122368           30.0      5
# 8511   4249         23    5.0  198.930176  123.139862           10.0      1
# 8659  14143         13    5.0  119.008003   69.033730           11.0     13
# 8726    238         88    5.0   90.762276   70.991791            5.0      1
# 8925   4214        105    5.0   85.313606   56.686691            5.0      4
# 9432    338         46    5.0  147.709305         NaN            0.0      6
# 9699   4971        169    5.0  117.855972   76.561317            9.0     12
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 1422         7.0       1940   0.015017         B         B        17
# 1503         5.0       1942   0.161976         B         A        31
# 1982        37.0       2011   0.161976         B         A        31
# 3268         1.0       1977   0.069753         B         B        53
# 3271        12.0       1977   0.011654         B         B         4
# 4431         1.0       1977   0.049637         B         B        34
# 4487         6.0       1997   0.090799         B         B        74
# 4762         5.0       1960   0.034331         B         B        25
# 5361        16.0       1998   0.092291         B         B        21
# 5466        17.0       1999   0.437885         B         B        23
# 6623         6.0       1940   0.050272         B         B        21
# 6988         3.0       2017   0.072158         B         B         2
# 8511         2.0       2011   0.014073         B         B         2
# 8659        17.0       2001   0.090799         B         B        74
# 8726         9.0       1972   0.127376         B         B        43
# 8925        12.0       1967   0.040243         B         B        25
# 9432         0.0       1977   0.150818         B         B        16
# 9699        14.0       2001   0.178917         B         B        18
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 1422      3079        59        2890.0            0        8       B
# 1503      7010         5        4508.0            3        7       B
# 1982      7010         5        4508.0            3        7       B
# 3268     13670         4           NaN            1       11       B
# 3271       915         0           NaN            0        0       B
# 4431      7759         0         229.0            1        3       B
# 4487     19083         2           NaN            5       15       B
# 4762      5487         3           NaN            0        4       B
# 5361      4346         2         165.0            1        2       B
# 5466      5735         3        1084.0            0        5       B
# 6623      4231        14        1020.0            0        3       B
# 6988       629         1           NaN            0        0       A
# 8511       475         0           NaN            0        0       B
# 8659     19083         2           NaN            5       15       B
# 8726      8429         3           NaN            3        9       B
# 8925      3478        11        2729.0            3        1       B
# 9432      3433         4        2643.0            4        5       B
# 9699      3594         4         192.0            1        5       B
#
#               Price
# 1422  479525.156250
# 1503  310305.062500
# 1982  455264.875000
# 3268  455446.406250
# 3271  112693.640625
# 4431  206148.843750
# 4487  622888.812500
# 4762  499830.937500
# 5361  496026.656250
# 5466  471833.781250
# 6623  513239.500000
# 6988  271919.875000
# 8511  345665.218750
# 8659  434774.343750
# 8726  289683.937500
# 8925  461678.750000
# 9432  352168.968750
# 9699  608674.125000

# %% [markdown]
# Ошибки в данных. Я решил удалить недостоверные данные и пересчитать их потом через площадь квартиры

# %%
train_df.loc[train_df['Rooms'] == 0, 'Rooms'] = np.nan
train_df.loc[train_df['Rooms'] >  5, 'Rooms'] = np.nan
train_df['Rooms'].value_counts()
# Out:
# 2.0    3880
# 1.0    3705
# 3.0    2235
# 4.0     150
# 5.0      18
# Name: Rooms, dtype: int64

# %%
train_df[train_df['Rooms'].isna()].head()
# Out:
#          Id DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 377    5927         57    NaN   59.056976   36.223072           10.0     22
# 1397  12638         27    NaN  138.427689  136.215500            0.0      4
# 1454   8491          1    NaN   42.006046   21.779287            7.0     17
# 1981   7917         27    NaN  212.932358  211.231125            0.0      2
# 2170  14003         99    NaN   59.414333   38.702244            6.0      7
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 377         22.0       2002   0.090799         B         B        74
# 1397         3.0       2016   0.075424         B         B        11
# 1454        17.0       2014   0.007122         B         B         1
# 1981         3.0       2008   0.211401         B         B         9
# 2170         9.0       1969   0.033494         B         B        66
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 377      19083         2           NaN            5       15       B
# 1397      3097         0           NaN            0        0       B
# 1454       264         0           NaN            0        1       B
# 1981      1892         0           NaN            0        1       B
# 2170     10573         1        1322.0            3        8       B
#
#               Price
# 377   317265.312500
# 1397  268394.750000
# 1454   78364.617188
# 1981  302211.250000
# 2170  229661.968750

# %% [markdown]
# #### Общая и жилая площадь

# %%
train_df[(train_df['Square'] > train_df['LifeSquare'] * 3) & (train_df['LifeSquare'] < 10) ]
# Out:
#          Id DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 26     4378         27    3.0  106.958870    0.641822            0.0     17
# 95     4280         34    2.0   61.334969    4.091945            1.0     26
# 134   12613          6    2.0   65.496674    5.589324            1.0      5
# 158   16779         27    3.0   51.991066    4.896202            1.0     22
# 160    3522          6    1.0   66.419838    3.987101            1.0      2
# ...     ...        ...    ...         ...         ...            ...    ...
# 9756  13583         27    2.0   58.943039    3.319486            1.0     11
# 9813   2040         62    1.0  122.438148    5.751401            1.0      2
# 9828  13630         24    3.0  127.141144    4.811405            1.0      3
# 9888   6053          6    1.0   41.314774    5.005477            1.0      9
# 9954    583         27    3.0   84.250710    4.187885            1.0     15
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 26           0.0       2018   0.072158         B         B         2
# 95           1.0       2014   0.069753         B         B        53
# 134         17.0       1977   0.243205         B         B         5
# 158         25.0       1977   0.072158         B         B         2
# 160          1.0       1977   0.243205         B         B         5
# ...          ...        ...        ...       ...       ...       ...
# 9756        17.0       2017   0.011654         B         B         4
# 9813         3.0       1977   0.072158         B         B         2
# 9828         1.0       2017   0.111627         B         B        50
# 9888        17.0       2016   0.243205         B         B         5
# 9954         1.0       2016   0.072158         B         B         2
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 26         629         1           NaN            0        0       A
# 95       13670         4           NaN            1       11       B
# 134       1564         0         540.0            0        0       B
# 158        629         1           NaN            0        0       A
# 160       1564         0         540.0            0        0       B
# ...        ...       ...           ...          ...      ...     ...
# 9756       915         0           NaN            0        0       B
# 9813       629         1           NaN            0        0       A
# 9828     12238         8        1970.0            2        3       B
# 9888      1564         0         540.0            0        0       B
# 9954       629         1           NaN            0        0       A
#
#               Price
# 26    337299.875000
# 95    286564.437500
# 134   180727.640625
# 158   174687.562500
# 160   193361.234375
# ...             ...
# 9756  142789.953125
# 9813  224900.890625
# 9828  611250.937500
# 9888  159149.515625
# 9954  236647.781250
#
# [195 rows x 20 columns]

# %%
train_df.loc[(train_df['Square'] > train_df['LifeSquare'] * 3) & (train_df['LifeSquare'] < 10), 'LifeSquare'] = np.nan

# %%
train_df[(train_df['LifeSquare'] > train_df['Square'] * 2) & (train_df['Square'] < 10)]
# Out:
#          Id DistrictId  Rooms    Square  LifeSquare  KitchenSquare  Floor  \
# 212    1748         88    2.0  5.497061   67.628716            1.0     24
# 3280  10527         27    1.0  4.380726   40.805836            1.0     10
# 6392  14786          1    1.0  1.136859    4.525736            1.0      3
# 8030  13265          1    3.0  4.823679   79.767967            0.0      6
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 212         22.0       1977   0.127376         B         B        43
# 3280        17.0       2013   0.211401         B         B         9
# 6392         1.0       1977   0.007122         B         B         1
# 8030        17.0       1977   0.007122         B         B         1
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 212       8429         3           NaN            3        9       B
# 3280      1892         0           NaN            0        1       B
# 6392       264         0           NaN            0        1       B
# 8030       264         0           NaN            0        1       B
#
#               Price
# 212   412511.093750
# 3280   97560.718750
# 6392  181434.828125
# 8030  237716.687500

# %%
train_df.loc[(train_df['LifeSquare'] > train_df['Square'] * 2) & (train_df['Square'] < 10), 'Square'] = train_df['LifeSquare'] + train_df['KitchenSquare']

# %%
train_df[(train_df['LifeSquare'] > train_df['Square'] * 2)]
# Out:
#          Id DistrictId  Rooms     Square   LifeSquare  KitchenSquare  Floor  \
# 590   14990         23    2.0  48.449875   263.542023            5.0      6
# 4328  16550         27    3.0  81.694420  7480.592285            1.0      9
# 6332   8961         27    1.0  33.398983   164.153366            6.0      3
# 8437  15886         85    3.0  78.059334   461.463623           10.0     12
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 590          5.0       1972   0.075779         B         B         6
# 4328        17.0       2016   0.017647         B         B         2
# 6332         5.0       1965   0.211401         B         B         9
# 8437        16.0       1998   0.037178         B         B        52
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 590       1437         3           NaN            0        2       B
# 4328       469         0           NaN            0        0       B
# 6332      1892         0           NaN            0        1       B
# 8437     11217         1        2300.0            1        7       B
#
#               Price
# 590   141780.234375
# 4328  217357.500000
# 6332  104891.070312
# 8437  394253.312500

# %%
train_df.loc[(train_df['LifeSquare'] > train_df['Square'] * 2), 'LifeSquare'] = np.nan
train_df[train_df['LifeSquare'].isna()].head()
# Out:
#        Id DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 7   11993         74    2.0   80.312927         NaN            0.0     14
# 8    5172          1    2.0   64.511436         NaN            1.0      9
# 21  11935         27    2.0   64.711838         NaN            1.0     15
# 23   6641         54    3.0  118.907608         NaN            0.0      2
# 25   5073         74    2.0   82.667915         NaN            1.0     16
#
#     HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  Social_2  \
# 7          0.0       1977   0.075779         B         B         6      1437
# 8         17.0       1977   0.007122         B         B         1       264
# 21         1.0       1977   0.211401         B         B         9      1892
# 23         0.0       1977   0.006076         B         B        30      5285
# 25        17.0       1977   0.075779         B         B         6      1437
#
#     Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2          Price
# 7          3           NaN            0        2       B  221244.156250
# 8          0           NaN            0        1       B  229102.796875
# 21         0           NaN            0        1       B  127200.023438
# 23         0         645.0            6        6       B  571069.062500
# 25         3           NaN            0        2       B  244145.828125

# %%
train_df[(train_df['LifeSquare'] > train_df['Square'])]
# Out:
#          Id DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 28     8054         23    1.0   42.530045   43.967758            1.0      3
# 44    10521         38    3.0  104.211395  106.340401            0.0     20
# 52     2301          1    2.0   61.400055   65.224602            0.0     17
# 123    8753         25    3.0   85.952309   89.803749            1.0      4
# 153    9870         62    1.0   51.831474   53.491302            1.0      5
# ...     ...        ...    ...         ...         ...            ...    ...
# 9884     41         30    2.0   59.015896   59.439083           12.0      5
# 9889  12918         23    2.0   51.440464   53.134243           51.0      3
# 9895   2737         27    3.0  123.430069  125.806984          123.0      5
# 9902  14001         73    1.0   44.098766   44.267551            1.0      7
# 9910  16568         27    4.0  200.334534  201.627365           25.0      1
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 28           9.0       2014   0.034656         B         B         0
# 44           0.0       2017   0.060753         B         B        15
# 52          22.0       2016   0.007122         B         B         1
# 123          3.0       2017   0.069753         B         B        53
# 153          1.0       2015   0.072158         B         B         2
# ...          ...        ...        ...       ...       ...       ...
# 9884         5.0       2016   0.000078         B         B        22
# 9889        17.0       2017   0.005767         B         B         1
# 9895        10.0       2015   0.017647         B         B         2
# 9902        24.0       2014   0.042032         B         B        37
# 9910         2.0       2013   0.041116         B         B        53
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 28         168         0           NaN            0        0       B
# 44        2787         2         520.0            0        7       B
# 52         264         0           NaN            0        1       B
# 123      13670         4           NaN            1       11       B
# 153        629         1           NaN            0        0       A
# ...        ...       ...           ...          ...      ...     ...
# 9884      6398       141        1046.0            3       23       B
# 9889       388         0           NaN            0        0       B
# 9895       469         0           NaN            0        0       B
# 9902      6856        84        1940.0            2        5       B
# 9910     14892         4           NaN            1        4       B
#
#               Price
# 28     95338.195312
# 44    435462.062500
# 52    199215.453125
# 123   309688.593750
# 153   131797.468750
# ...             ...
# 9884  126281.140625
# 9889   88150.015625
# 9895  234194.843750
# 9902  381937.406250
# 9910  528560.500000
#
# [474 rows x 20 columns]

# %% [markdown]
# Поменяем местами

# %%
train_df['Square'], train_df['LifeSquare'] = np.where(train_df['Square'] < train_df['LifeSquare'],(train_df['LifeSquare'],train_df['Square']), (train_df['Square'],train_df['LifeSquare']))
(train_df['Square'] < train_df['LifeSquare']).value_counts()
# Out:
# False    10000
# dtype: int64

# %% [markdown]
# ### Площадь кухни

# %%
train_df['KitchenSquare'].value_counts()
# Out:
# 1.0       2460
# 8.0       1306
# 5.0       1169
# 10.0      1075
# 6.0       1038
# 9.0        843
# 0.0        697
# 7.0        609
# 12.0       249
# 11.0       233
# 13.0        67
# 14.0        51
# 4.0         39
# 15.0        31
# 3.0         22
# 16.0        16
# 20.0        14
# 17.0        12
# 19.0        11
# 18.0         6
# 2.0          4
# 22.0         3
# 41.0         2
# 112.0        2
# 25.0         2
# 43.0         2
# 51.0         2
# 37.0         2
# 32.0         2
# 30.0         2
# 58.0         2
# 72.0         1
# 96.0         1
# 66.0         1
# 48.0         1
# 40.0         1
# 2014.0       1
# 35.0         1
# 60.0         1
# 78.0         1
# 27.0         1
# 84.0         1
# 62.0         1
# 42.0         1
# 63.0         1
# 39.0         1
# 1970.0       1
# 36.0         1
# 75.0         1
# 26.0         1
# 21.0         1
# 29.0         1
# 23.0         1
# 73.0         1
# 123.0        1
# 31.0         1
# 53.0         1
# 54.0         1
# Name: KitchenSquare, dtype: int64

# %% [markdown]
# Аномалии

# %%
train_df[train_df['Square'] < train_df['KitchenSquare']]
# Out:
#          Id DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 1064  14656         62    1.0  47.100719   46.447960         2014.0      4
# 5149  13703         42    1.0  38.071693   19.723547           73.0      9
# 7088   6569         27    1.0  38.220257   18.716856           84.0      4
# 8584  14679         81    1.0  32.276665   19.278395         1970.0      6
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 1064         1.0       2014   0.072158         B         B         2
# 5149        10.0       2006   0.158249         B         B        21
# 7088        17.0       2018   0.011654         B         B         4
# 8584         1.0       1977   0.006076         B         B        30
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 1064       629         1           NaN            0        0       A
# 5149      5731         0           NaN            1        0       B
# 7088       915         0           NaN            0        0       B
# 8584      5285         0         645.0            6        6       B
#
#               Price
# 1064  108337.484375
# 5149  160488.031250
# 7088   99079.960938
# 8584  105539.554688

# %%
train_df.loc[train_df['Square'] < train_df['KitchenSquare'], 'KitchenSquare'] = np.nan

# %%
train_df[train_df['Square'] *0.5 < train_df['KitchenSquare']]
# Out:
#          Id DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 227   16395          2    3.0   79.722244   44.731220           72.0     12
# 551    1315          6    1.0   48.128113   45.023533           48.0     21
# 1077   9690         27    1.0   40.081043   37.834965           37.0     18
# 1369   2371         27    2.0   68.841072   64.234955           66.0      4
# 1455  12507         54    2.0   79.810532   79.578964           78.0     10
# 1860   4265        161    2.0   53.216778   32.644859           53.0      7
# 2916  12390         72    3.0   99.323555   97.490677           96.0     22
# 2969   7441         62    3.0  114.734474  112.589081          112.0      3
# 3379  16781         27    1.0   36.710541   36.138409           36.0     19
# 4079   6508         23    2.0   67.146049   33.959152           63.0      5
# 4110    299         27    2.0   66.787521   64.616661           60.0     14
# 4142  15466         88    1.0   44.779713   42.357487           41.0     10
# 4588    448         48    1.0   41.186905         NaN           41.0      2
# 4651  12552         58    3.0  116.405693  113.109650          112.0      3
# 5162  11739         27    2.0   61.070297   59.845093           58.0      8
# 5480  15781         10    1.0   35.813564   19.953993           35.0      6
# 5816   2271         27    1.0   43.292515   42.835644           40.0     12
# 5849  11624         46    1.0   42.983284   24.224436           37.0     15
# 5888  16593         52    2.0   64.859245         NaN           62.0     15
# 5904    673         27    1.0   54.418213   51.498581           51.0     10
# 6036  12666         34    2.0   60.603363         NaN           58.0     14
# 6240   4966         96    3.0   78.445679   47.146755           75.0      9
# 7480  10546         62    1.0   46.013187   43.417042           43.0      4
# 8232   7162         34    2.0   57.510395   56.738762           54.0     26
# 9111   6708         48    1.0   42.069359   22.487740           39.0      1
# 9889  12918         23    2.0   53.134243   51.440464           51.0      3
# 9895   2737         27    3.0  125.806984  123.430069          123.0      5
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 227         16.0       1987   0.130618         B         B        39
# 551          1.0       2013   0.243205         B         B         5
# 1077        19.0       2019   0.211401         B         B         9
# 1369         2.0       2014   0.017647         B         B         2
# 1455        15.0       2014   0.006076         B         B        30
# 1860        17.0       1994   0.000699         B         B        14
# 2916        25.0       2019   0.210473         B         B        11
# 2969         3.0       2015   0.072158         B         B         2
# 3379        19.0       2017   0.072158         B         B         2
# 4079        17.0       2019   0.034656         B         B         0
# 4110        20.0       2015   0.017647         B         B         2
# 4142        19.0       2016   0.127376         B         B        43
# 4588         1.0       1977   0.041125         B         B        46
# 4651         3.0       2016   0.437885         B         B        23
# 5162        17.0       2016   0.072158         B         B         2
# 5480        14.0       1971   0.282798         B         B        33
# 5816        11.0       2015   0.211401         B         B         9
# 5849        16.0       1983   0.188784         B         B        31
# 5888        17.0       1977   0.371149         B         B        34
# 5904        17.0       2017   0.072158         B         B         2
# 6036        22.0       1977   0.069753         B         B        53
# 6240        12.0       1977   0.041116         B         B        53
# 7480        17.0       2019   0.072158         B         B         2
# 8232        25.0       2016   0.069753         B         B        53
# 9111        10.0       2010   0.041125         B         B        46
# 9889        17.0       2017   0.005767         B         B         1
# 9895        10.0       2015   0.017647         B         B         2
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 227      10418         9         900.0            1        9       B
# 551       1564         0         540.0            0        0       B
# 1077      1892         0           NaN            0        1       B
# 1369       469         0           NaN            0        0       B
# 1455      5285         0         645.0            6        6       B
# 1860      3369        24        4129.0            0        3       B
# 2916      2398         2        1994.0            3        0       B
# 2969       629         1           NaN            0        0       A
# 3379       629         1           NaN            0        0       A
# 4079       168         0           NaN            0        0       B
# 4110       469         0           NaN            0        0       B
# 4142      8429         3           NaN            3        9       B
# 4588      9515         5           NaN            1       10       B
# 4651      5735         3        1084.0            0        5       B
# 5162       629         1           NaN            0        0       A
# 5480      8667         2           NaN            0        6       B
# 5816      1892         0           NaN            0        1       B
# 5849      6137         4           NaN            0        1       B
# 5888      7065         1         750.0            2        5       B
# 5904       629         1           NaN            0        0       A
# 6036     13670         4           NaN            1       11       B
# 6240     14892         4           NaN            1        4       B
# 7480       629         1           NaN            0        0       A
# 8232     13670         4           NaN            1       11       B
# 9111      9515         5           NaN            1       10       B
# 9889       388         0           NaN            0        0       B
# 9895       469         0           NaN            0        0       B
#
#               Price
# 227   370148.625000
# 551   146950.906250
# 1077   93218.648438
# 1369  189244.250000
# 1455  438708.718750
# 1860  261125.671875
# 2916  445074.968750
# 2969  315245.531250
# 3379  131742.531250
# 4079  193130.578125
# 4110  179466.093750
# 4142  194525.109375
# 4588  216882.265625
# 4651  296165.937500
# 5162  212188.953125
# 5480  164306.312500
# 5816  117296.171875
# 5849  198450.734375
# 5888  185993.468750
# 5904  133273.640625
# 6036  261733.468750
# 6240  290354.468750
# 7480  113909.101562
# 8232  244220.625000
# 9111  200021.828125
# 9889   88150.015625
# 9895  234194.843750

# %%
train_df.loc[train_df['Square'] * 0.5 < train_df['KitchenSquare'], 'KitchenSquare'] = np.nan

# %%
train_df[train_df['KitchenSquare'].isna()]
# Out:
#          Id DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 227   16395          2    3.0   79.722244   44.731220            NaN     12
# 551    1315          6    1.0   48.128113   45.023533            NaN     21
# 1064  14656         62    1.0   47.100719   46.447960            NaN      4
# 1077   9690         27    1.0   40.081043   37.834965            NaN     18
# 1369   2371         27    2.0   68.841072   64.234955            NaN      4
# 1455  12507         54    2.0   79.810532   79.578964            NaN     10
# 1860   4265        161    2.0   53.216778   32.644859            NaN      7
# 2916  12390         72    3.0   99.323555   97.490677            NaN     22
# 2969   7441         62    3.0  114.734474  112.589081            NaN      3
# 3379  16781         27    1.0   36.710541   36.138409            NaN     19
# 4079   6508         23    2.0   67.146049   33.959152            NaN      5
# 4110    299         27    2.0   66.787521   64.616661            NaN     14
# 4142  15466         88    1.0   44.779713   42.357487            NaN     10
# 4588    448         48    1.0   41.186905         NaN            NaN      2
# 4651  12552         58    3.0  116.405693  113.109650            NaN      3
# 5149  13703         42    1.0   38.071693   19.723547            NaN      9
# 5162  11739         27    2.0   61.070297   59.845093            NaN      8
# 5480  15781         10    1.0   35.813564   19.953993            NaN      6
# 5816   2271         27    1.0   43.292515   42.835644            NaN     12
# 5849  11624         46    1.0   42.983284   24.224436            NaN     15
# 5888  16593         52    2.0   64.859245         NaN            NaN     15
# 5904    673         27    1.0   54.418213   51.498581            NaN     10
# 6036  12666         34    2.0   60.603363         NaN            NaN     14
# 6240   4966         96    3.0   78.445679   47.146755            NaN      9
# 7088   6569         27    1.0   38.220257   18.716856            NaN      4
# 7480  10546         62    1.0   46.013187   43.417042            NaN      4
# 8232   7162         34    2.0   57.510395   56.738762            NaN     26
# 8584  14679         81    1.0   32.276665   19.278395            NaN      6
# 9111   6708         48    1.0   42.069359   22.487740            NaN      1
# 9889  12918         23    2.0   53.134243   51.440464            NaN      3
# 9895   2737         27    3.0  125.806984  123.430069            NaN      5
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 227         16.0       1987   0.130618         B         B        39
# 551          1.0       2013   0.243205         B         B         5
# 1064         1.0       2014   0.072158         B         B         2
# 1077        19.0       2019   0.211401         B         B         9
# 1369         2.0       2014   0.017647         B         B         2
# 1455        15.0       2014   0.006076         B         B        30
# 1860        17.0       1994   0.000699         B         B        14
# 2916        25.0       2019   0.210473         B         B        11
# 2969         3.0       2015   0.072158         B         B         2
# 3379        19.0       2017   0.072158         B         B         2
# 4079        17.0       2019   0.034656         B         B         0
# 4110        20.0       2015   0.017647         B         B         2
# 4142        19.0       2016   0.127376         B         B        43
# 4588         1.0       1977   0.041125         B         B        46
# 4651         3.0       2016   0.437885         B         B        23
# 5149        10.0       2006   0.158249         B         B        21
# 5162        17.0       2016   0.072158         B         B         2
# 5480        14.0       1971   0.282798         B         B        33
# 5816        11.0       2015   0.211401         B         B         9
# 5849        16.0       1983   0.188784         B         B        31
# 5888        17.0       1977   0.371149         B         B        34
# 5904        17.0       2017   0.072158         B         B         2
# 6036        22.0       1977   0.069753         B         B        53
# 6240        12.0       1977   0.041116         B         B        53
# 7088        17.0       2018   0.011654         B         B         4
# 7480        17.0       2019   0.072158         B         B         2
# 8232        25.0       2016   0.069753         B         B        53
# 8584         1.0       1977   0.006076         B         B        30
# 9111        10.0       2010   0.041125         B         B        46
# 9889        17.0       2017   0.005767         B         B         1
# 9895        10.0       2015   0.017647         B         B         2
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 227      10418         9         900.0            1        9       B
# 551       1564         0         540.0            0        0       B
# 1064       629         1           NaN            0        0       A
# 1077      1892         0           NaN            0        1       B
# 1369       469         0           NaN            0        0       B
# 1455      5285         0         645.0            6        6       B
# 1860      3369        24        4129.0            0        3       B
# 2916      2398         2        1994.0            3        0       B
# 2969       629         1           NaN            0        0       A
# 3379       629         1           NaN            0        0       A
# 4079       168         0           NaN            0        0       B
# 4110       469         0           NaN            0        0       B
# 4142      8429         3           NaN            3        9       B
# 4588      9515         5           NaN            1       10       B
# 4651      5735         3        1084.0            0        5       B
# 5149      5731         0           NaN            1        0       B
# 5162       629         1           NaN            0        0       A
# 5480      8667         2           NaN            0        6       B
# 5816      1892         0           NaN            0        1       B
# 5849      6137         4           NaN            0        1       B
# 5888      7065         1         750.0            2        5       B
# 5904       629         1           NaN            0        0       A
# 6036     13670         4           NaN            1       11       B
# 6240     14892         4           NaN            1        4       B
# 7088       915         0           NaN            0        0       B
# 7480       629         1           NaN            0        0       A
# 8232     13670         4           NaN            1       11       B
# 8584      5285         0         645.0            6        6       B
# 9111      9515         5           NaN            1       10       B
# 9889       388         0           NaN            0        0       B
# 9895       469         0           NaN            0        0       B
#
#               Price
# 227   370148.625000
# 551   146950.906250
# 1064  108337.484375
# 1077   93218.648438
# 1369  189244.250000
# 1455  438708.718750
# 1860  261125.671875
# 2916  445074.968750
# 2969  315245.531250
# 3379  131742.531250
# 4079  193130.578125
# 4110  179466.093750
# 4142  194525.109375
# 4588  216882.265625
# 4651  296165.937500
# 5149  160488.031250
# 5162  212188.953125
# 5480  164306.312500
# 5816  117296.171875
# 5849  198450.734375
# 5888  185993.468750
# 5904  133273.640625
# 6036  261733.468750
# 6240  290354.468750
# 7088   99079.960938
# 7480  113909.101562
# 8232  244220.625000
# 8584  105539.554688
# 9111  200021.828125
# 9889   88150.015625
# 9895  234194.843750

# %% [markdown]
# #### Этаж, Этажность

# %%
plt.figure(figsize = (16, 8))
train_df['HouseFloor'].hist(bins=50)
plt.show()

# %%
plt.figure(figsize = (16, 8))
train_df['Floor'].hist(bins=50)
plt.show()

# %% [markdown]
# Аномалии

# %%
train_df[train_df['HouseFloor'] > 50]
# Out:
#          Id DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 6131  10806          5    1.0  51.944588   48.709602            1.0      6
# 8599   9300         74    2.0  74.579811   71.747871            9.0      5
# 8854     78         30    2.0  66.811790   65.773750            1.0      8
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 6131        99.0       1977   0.150818         B         B        16
# 8599        99.0       1977   0.075779         B         B         6
# 8854       117.0       1977   0.000078         B         B        22
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 6131      3433         4        2643.0            4        5       B
# 8599      1437         3           NaN            0        2       B
# 8854      6398       141        1046.0            3       23       B
#
#              Price
# 6131  296127.12500
# 8599  243329.90625
# 8854  207248.37500

# %%
train_df.loc[train_df['HouseFloor'] > 50, 'HouseFloor'] = train_df['Floor']
train_df.loc[train_df['HouseFloor'] == 0, 'HouseFloor'] = train_df['Floor']

# %%
train_df[train_df['Floor'] > train_df['HouseFloor']]
# Out:
#          Id DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 14    10953         27    1.0   53.769096   52.408028            1.0      5
# 16     2119         27    2.0   49.360649   31.993963            5.0      6
# 21    11935         27    2.0   64.711838         NaN            1.0     15
# 35     6486        200    3.0   85.280388   58.447968            9.0      6
# 51    10103         94    1.0   35.280895   23.354176            6.0     11
# ...     ...        ...    ...         ...         ...            ...    ...
# 9984   2237         52    3.0   64.074974   47.633427            6.0     11
# 9985  16159         27    1.0   38.968338         NaN            1.0     10
# 9989   4145         96    3.0   90.055229   47.860229           11.0     26
# 9991  11553          3    3.0  101.622795   51.628780           12.0     18
# 9995     77         32    2.0   50.401787   30.476204            5.0      6
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 14           4.0       1977   0.072158         B         B         2
# 16           5.0       1983   0.051815         B         B         5
# 21           1.0       1977   0.211401         B         B         9
# 35           5.0       1960   0.000000         B         B        33
# 51           9.0       1971   0.282798         B         B        33
# ...          ...        ...        ...       ...       ...       ...
# 9984         9.0       1983   0.371149         B         B        34
# 9985         1.0       1977   0.211401         B         B         9
# 9989        24.0       2005   0.041116         B         B        53
# 9991        17.0       2000   0.265089         B         B        37
# 9995         5.0       1968   0.135650         B         B        46
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 14         629         1           NaN            0        0       A
# 16        1227         0           NaN            0        0       B
# 21        1892         0           NaN            0        1       B
# 35        7425         1           NaN            2        5       B
# 51        8667         2           NaN            0        6       B
# ...        ...       ...           ...          ...      ...     ...
# 9984      7065         1         750.0            2        5       B
# 9985      1892         0           NaN            0        1       B
# 9989     14892         4           NaN            1        4       B
# 9991      5288         0        1937.0            3        2       B
# 9995      7960         6         350.0            3       11       B
#
#               Price
# 14    140647.562500
# 16    117000.382812
# 21    127200.023438
# 35    402871.906250
# 51    148862.203125
# ...             ...
# 9984  226434.875000
# 9985   95529.570312
# 9989  441108.906250
# 9991  212883.500000
# 9995  196684.312500
#
# [1556 rows x 20 columns]

# %% [markdown]
# Поменяем местами

# %%
train_df['HouseFloor'], train_df['Floor'] = np.where(train_df['HouseFloor'] < train_df['Floor'],(train_df['Floor'],train_df['HouseFloor']), (train_df['HouseFloor'],train_df['Floor']))
(train_df['HouseFloor'] < train_df['Floor']).value_counts()
# Out:
# False    10000
# dtype: int64

# %% [markdown]
# #### Год постойки

# %%
train_df['HouseYear'].sort_values(ascending=False)
# Out:
# 1497    20052011
# 4189        4968
# 1499        2020
# 5701        2020
# 7076        2020
#           ...
# 7611        1916
# 910         1914
# 5111        1912
# 2656        1912
# 9317        1910
# Name: HouseYear, Length: 10000, dtype: int32

# %%
train_df.loc[train_df['HouseYear'] > datetime.now().year, 'HouseYear'] = train_df['HouseYear'].median()
train_df['HouseYear'].sort_values(ascending=False)
# Out:
# 9674    2020
# 4493    2020
# 6735    2020
# 4376    2020
# 7076    2020
#         ...
# 7611    1916
# 910     1914
# 5111    1912
# 2656    1912
# 9317    1910
# Name: HouseYear, Length: 10000, dtype: int32

# %% [markdown]
# #### Ecology_1

# %%
plt.figure(figsize = (16, 8))
train_df['Ecology_1'].hist(bins=30)
plt.show()

# %% [markdown]
# #### Social_1

# %%
plt.figure(figsize = (16, 8))
train_df['Social_1'].hist(bins=30)
plt.show()

# %% [markdown]
# #### Social_2

# %%
plt.figure(figsize = (16, 8))
train_df['Social_2'].hist(bins=30)
plt.show()

# %% [markdown]
# #### Social_3

# %%
plt.figure(figsize = (16, 8))
train_df['Social_3'].hist(bins=30)
plt.show()

# %% [markdown]
# #### Healthcare_1

# %%
plt.figure(figsize = (16, 8))
train_df['Healthcare_1'].hist(bins=30)
plt.show()

# %% [markdown]
# #### Helthcare_2

# %%
plt.figure(figsize = (16, 8))
train_df['Helthcare_2'].hist(bins=30)
plt.show()

# %% [markdown]
# #### Shops_1

# %%
plt.figure(figsize = (16, 8))
train_df['Shops_1'].hist(bins=30)
plt.show()

# %%
train_df.describe()
# Out:
#              Rooms        Square   LifeSquare  KitchenSquare         Floor  \
# count  9988.000000  10000.000000  7688.000000     9969.00000  10000.000000
# mean      1.888266     56.410892    36.886181        5.71281      7.943200
# std       0.811548     21.054884    18.886993        4.00030      5.228094
# min       1.000000      2.377248     0.873147        0.00000      1.000000
# 25%       1.000000     41.865869    23.266581        1.00000      4.000000
# 50%       2.000000     52.619610    33.082787        6.00000      7.000000
# 75%       2.000000     65.990473    45.270760        9.00000     11.000000
# max       5.000000    641.065186   638.163208       43.00000     42.000000
#
#          HouseFloor     HouseYear     Ecology_1      Social_1      Social_2  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean      13.406100   1984.863800      0.118858     24.687000   5352.157400
# std        5.883285     18.409979      0.119026     17.532614   4006.799803
# min        1.000000   1910.000000      0.000000      0.000000    168.000000
# 25%        9.000000   1974.000000      0.017647      6.000000   1564.000000
# 50%       14.000000   1977.000000      0.075424     25.000000   5285.000000
# 75%       17.000000   2001.000000      0.195781     36.000000   7227.000000
# max       48.000000   2020.000000      0.521867     74.000000  19083.000000
#
#            Social_3  Healthcare_1   Helthcare_2       Shops_1          Price
# count  10000.000000   5202.000000  10000.000000  10000.000000   10000.000000
# mean       8.039200   1142.904419      1.319500      4.231300  214139.218750
# std       23.831875   1021.518982      1.493601      4.806341   92872.304688
# min        0.000000      0.000000      0.000000      0.000000   59174.777344
# 25%        0.000000    350.000000      0.000000      1.000000  153872.628906
# 50%        2.000000    900.000000      1.000000      3.000000  192269.648438
# 75%        5.000000   1548.000000      2.000000      6.000000  249135.460938
# max      141.000000   4849.000000      6.000000     23.000000  633233.437500

# %% [markdown]
# ### Категориальные признаки

# %%
train_df.select_dtypes(include='category').columns.tolist()
# Out:
# ['Id', 'DistrictId', 'Ecology_2', 'Ecology_3', 'Shops_2']

# %% [markdown]
# #### Район. Ничего не далаем

# %%
train_df['DistrictId'].value_counts()
# Out:
# 27     851
# 1      652
# 23     565
# 6      511
# 9      294
#       ...
# 199      1
# 117      1
# 205      1
# 207      1
# 209      1
# Name: DistrictId, Length: 205, dtype: int64

# %% [markdown]
# #### Ecology_2. Разобьем на бинарные

# %%
train_df['Ecology_2'].value_counts()
# Out:
# B    9903
# A      97
# Name: Ecology_2, dtype: int64

# %%
train_df = pd.concat([train_df, pd.get_dummies(train_df['Ecology_2'])], axis=1)
train_df.rename(columns={'A': 'Ecology_2_A', 'B': 'Ecology_2_B'}, inplace=True)
train_df.drop('Ecology_2', axis=1, inplace=True)
train_df.head()
# Out:
#       Id DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 0  14038         35    2.0  47.981560   29.442751            6.0    7.0
# 1  15053         41    3.0  65.683640   40.049541            8.0    7.0
# 2   4765         53    2.0  44.947952   29.197611            0.0    8.0
# 3   5809         58    2.0  53.352982   52.731510            9.0    8.0
# 4  10783         99    1.0  39.649193   23.776169            7.0   11.0
#
#    HouseFloor  HouseYear  Ecology_1  ... Social_1  Social_2  Social_3  \
# 0         9.0       1969   0.089040  ...       33      7976         5
# 1         9.0       1978   0.000070  ...       46     10309         1
# 2        12.0       1968   0.049637  ...       34      7759         0
# 3        17.0       1977   0.437885  ...       23      5735         3
# 4        12.0       1976   0.012339  ...       35      5776         1
#
#    Healthcare_1  Helthcare_2  Shops_1  Shops_2          Price  Ecology_2_A  \
# 0           NaN            0       11        B  184966.937500            0
# 1         240.0            1       16        B  300009.437500            0
# 2         229.0            1        3        B  220925.906250            0
# 3        1084.0            0        5        B  175616.234375            0
# 4        2078.0            2        4        B  150226.531250            0
#
#    Ecology_2_B
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1
#
# [5 rows x 21 columns]

# %% [markdown]
# #### Ecology_3. Разобьем на бинарные

# %%
train_df['Ecology_3'].value_counts()
# Out:
# B    9725
# A     275
# Name: Ecology_3, dtype: int64

# %%
train_df = pd.concat([train_df, pd.get_dummies(train_df['Ecology_3'])], axis=1)
train_df.rename(columns={'A': 'Ecology_3_A', 'B': 'Ecology_3_B'}, inplace=True)
train_df.drop('Ecology_3', axis=1, inplace=True)
train_df.head()
# Out:
#       Id DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 0  14038         35    2.0  47.981560   29.442751            6.0    7.0
# 1  15053         41    3.0  65.683640   40.049541            8.0    7.0
# 2   4765         53    2.0  44.947952   29.197611            0.0    8.0
# 3   5809         58    2.0  53.352982   52.731510            9.0    8.0
# 4  10783         99    1.0  39.649193   23.776169            7.0   11.0
#
#    HouseFloor  HouseYear  Ecology_1  ...  Social_3  Healthcare_1  Helthcare_2  \
# 0         9.0       1969   0.089040  ...         5           NaN            0
# 1         9.0       1978   0.000070  ...         1         240.0            1
# 2        12.0       1968   0.049637  ...         0         229.0            1
# 3        17.0       1977   0.437885  ...         3        1084.0            0
# 4        12.0       1976   0.012339  ...         1        2078.0            2
#
#    Shops_1  Shops_2          Price Ecology_2_A  Ecology_2_B  Ecology_3_A  \
# 0       11        B  184966.937500           0            1            0
# 1       16        B  300009.437500           0            1            0
# 2        3        B  220925.906250           0            1            0
# 3        5        B  175616.234375           0            1            0
# 4        4        B  150226.531250           0            1            0
#
#    Ecology_3_B
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1
#
# [5 rows x 22 columns]

# %% [markdown]
# #### Shops_2. Разобьем на бинарные

# %%
train_df['Shops_2'].value_counts()
# Out:
# B    9175
# A     825
# Name: Shops_2, dtype: int64

# %%
train_df = pd.concat([train_df, pd.get_dummies(train_df['Shops_2'])], axis=1)
train_df.rename(columns={'A': 'Shops_2_A', 'B': 'Shops_2_B'}, inplace=True)
train_df.drop('Shops_2', axis=1, inplace=True)
train_df.head()
# Out:
#       Id DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 0  14038         35    2.0  47.981560   29.442751            6.0    7.0
# 1  15053         41    3.0  65.683640   40.049541            8.0    7.0
# 2   4765         53    2.0  44.947952   29.197611            0.0    8.0
# 3   5809         58    2.0  53.352982   52.731510            9.0    8.0
# 4  10783         99    1.0  39.649193   23.776169            7.0   11.0
#
#    HouseFloor  HouseYear  Ecology_1  ...  Healthcare_1  Helthcare_2  Shops_1  \
# 0         9.0       1969   0.089040  ...           NaN            0       11
# 1         9.0       1978   0.000070  ...         240.0            1       16
# 2        12.0       1968   0.049637  ...         229.0            1        3
# 3        17.0       1977   0.437885  ...        1084.0            0        5
# 4        12.0       1976   0.012339  ...        2078.0            2        4
#
#            Price  Ecology_2_A  Ecology_2_B  Ecology_3_A  Ecology_3_B  \
# 0  184966.937500            0            1            0            1
# 1  300009.437500            0            1            0            1
# 2  220925.906250            0            1            0            1
# 3  175616.234375            0            1            0            1
# 4  150226.531250            0            1            0            1
#
#    Shops_2_A  Shops_2_B
# 0          0          1
# 1          0          1
# 2          0          1
# 3          0          1
# 4          0          1
#
# [5 rows x 23 columns]

# %% [markdown]
# ### Обработка пропусков

# %%
train_df.isna().sum()
# Out:
# Id                  0
# DistrictId          0
# Rooms              12
# Square              0
# LifeSquare       2312
# KitchenSquare      31
# Floor               0
# HouseFloor          0
# HouseYear           0
# Ecology_1           0
# Social_1            0
# Social_2            0
# Social_3            0
# Healthcare_1     4798
# Helthcare_2         0
# Shops_1             0
# Price               0
# Ecology_2_A         0
# Ecology_2_B         0
# Ecology_3_A         0
# Ecology_3_B         0
# Shops_2_A           0
# Shops_2_B           0
# dtype: int64

# %% [markdown]
# #### Rooms

# %%
Rooms_Percent =  (train_df['Rooms'] / train_df['Square']).mean() 
Rooms_Percent
# Out:
# 0.033459097146987915

# %%
train_df.loc[train_df['Rooms'].isna(), 'Rooms'] = np.round(train_df['Square'] * Rooms_Percent)
train_df.loc[train_df['Rooms'] == 0, 'Rooms'] = 1
train_df.loc[train_df['Rooms'] >  5, 'Rooms'] = 5
train_df['Rooms'].value_counts()
# Out:
# 2.0    3884
# 1.0    3709
# 3.0    2237
# 4.0     150
# 5.0      20
# Name: Rooms, dtype: int64

# %% [markdown]
# #### KitchenSquare

# %%
Kitchen_Percent =  (train_df['KitchenSquare'] / train_df['Square']).mean() 
Kitchen_Percent
# Out:
# 0.11000772565603256

# %%
train_df.loc[train_df['KitchenSquare'].isna(), 'KitchenSquare'] = np.round(train_df['Square'] * Kitchen_Percent)

# %% [markdown]
# #### LifeSquare

# %%
train_df.loc[train_df['LifeSquare'].isna(), 'LifeSquare'] = train_df['Square'] - train_df['KitchenSquare']

# %% [markdown]
# #### Healthcare_1

# %%
train_df.loc[train_df['Healthcare_1'].isna(), 'Healthcare_1'] = train_df['Healthcare_1'].median()
train_df['Healthcare_1'].value_counts()
# Out:
# 900.0     4869
# 540.0      511
# 30.0       348
# 1046.0     245
# 750.0      163
#           ...
# 370.0       14
# 32.0        12
# 1815.0      10
# 35.0         2
# 0.0          1
# Name: Healthcare_1, Length: 79, dtype: int64

# %%
train_df.isna().sum()
# Out:
# Id               0
# DistrictId       0
# Rooms            0
# Square           0
# LifeSquare       0
# KitchenSquare    0
# Floor            0
# HouseFloor       0
# HouseYear        0
# Ecology_1        0
# Social_1         0
# Social_2         0
# Social_3         0
# Healthcare_1     0
# Helthcare_2      0
# Shops_1          0
# Price            0
# Ecology_2_A      0
# Ecology_2_B      0
# Ecology_3_A      0
# Ecology_3_B      0
# Shops_2_A        0
# Shops_2_B        0
# dtype: int64

# %%
train_df.head(1000)
# Out:
#         Id DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 0    14038         35    2.0  47.981560   29.442751            6.0    7.0
# 1    15053         41    3.0  65.683640   40.049541            8.0    7.0
# 2     4765         53    2.0  44.947952   29.197611            0.0    8.0
# 3     5809         58    2.0  53.352982   52.731510            9.0    8.0
# 4    10783         99    1.0  39.649193   23.776169            7.0   11.0
# ..     ...        ...    ...        ...         ...            ...    ...
# 995  14045         67    3.0  65.492317   39.609917            8.0    9.0
# 996   2527         88    2.0  46.114674   30.199327            6.0    4.0
# 997  13477        156    2.0  55.735188   31.140215            9.0   17.0
# 998   2565         11    3.0  71.649818   50.897793            6.0    7.0
# 999  10347         74    2.0  66.546997   65.220619            1.0   17.0
#
#      HouseFloor  HouseYear  Ecology_1  ...  Healthcare_1  Helthcare_2  \
# 0           9.0       1969   0.089040  ...         900.0            0
# 1           9.0       1978   0.000070  ...         240.0            1
# 2          12.0       1968   0.049637  ...         229.0            1
# 3          17.0       1977   0.437885  ...        1084.0            0
# 4          12.0       1976   0.012339  ...        2078.0            2
# ..          ...        ...        ...  ...           ...          ...
# 995         9.0       1977   0.100456  ...         900.0            1
# 996        12.0       1975   0.127376  ...         900.0            3
# 997        18.0       2005   0.007659  ...        2301.0            3
# 998         9.0       1973   0.000170  ...         900.0            1
# 999        17.0       2014   0.309479  ...         990.0            0
#
#      Shops_1          Price  Ecology_2_A  Ecology_2_B  Ecology_3_A  \
# 0         11  184966.937500            0            1            0
# 1         16  300009.437500            0            1            0
# 2          3  220925.906250            0            1            0
# 3          5  175616.234375            0            1            0
# 4          4  150226.531250            0            1            0
# ..       ...            ...          ...          ...          ...
# 995        6  248863.984375            0            1            0
# 996        9  205410.875000            0            1            0
# 997       19  353868.187500            0            1            0
# 998        1  259899.296875            0            1            0
# 999        6  156028.375000            0            1            0
#
#      Ecology_3_B  Shops_2_A  Shops_2_B
# 0              1          0          1
# 1              1          0          1
# 2              1          0          1
# 3              1          0          1
# 4              1          0          1
# ..           ...        ...        ...
# 995            1          1          0
# 996            1          0          1
# 997            1          0          1
# 998            1          0          1
# 999            1          0          1
#
# [1000 rows x 23 columns]

# %% [markdown]
# ### Новые фичи

# %% [markdown]
# #### Популярность района

# %%
district_size = train_df['DistrictId'].value_counts().reset_index().rename(columns={'index':'DistrictId', 'DistrictId':'DistrictSize'})

district_size.head()
# Out:
#   DistrictId  DistrictSize
# 0         27           851
# 1          1           652
# 2         23           565
# 3          6           511
# 4          9           294

# %%
train_df = train_df.merge(district_size, on='DistrictId', how='left')
train_df.head()
# Out:
#       Id DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 0  14038         35    2.0  47.981560   29.442751            6.0    7.0
# 1  15053         41    3.0  65.683640   40.049541            8.0    7.0
# 2   4765         53    2.0  44.947952   29.197611            0.0    8.0
# 3   5809         58    2.0  53.352982   52.731510            9.0    8.0
# 4  10783         99    1.0  39.649193   23.776169            7.0   11.0
#
#    HouseFloor  HouseYear  Ecology_1  ...  Helthcare_2  Shops_1          Price  \
# 0         9.0       1969   0.089040  ...            0       11  184966.937500
# 1         9.0       1978   0.000070  ...            1       16  300009.437500
# 2        12.0       1968   0.049637  ...            1        3  220925.906250
# 3        17.0       1977   0.437885  ...            0        5  175616.234375
# 4        12.0       1976   0.012339  ...            2        4  150226.531250
#
#    Ecology_2_A  Ecology_2_B  Ecology_3_A  Ecology_3_B  Shops_2_A  Shops_2_B  \
# 0            0            1            0            1          0          1
# 1            0            1            0            1          0          1
# 2            0            1            0            1          0          1
# 3            0            1            0            1          0          1
# 4            0            1            0            1          0          1
#
#    DistrictSize
# 0            22
# 1            87
# 2           174
# 3           179
# 4            97
#
# [5 rows x 24 columns]

# %% [markdown]
# #### Большой район

# %%
train_df['IsDistrictLarge'] = (train_df['DistrictSize'] > 100).astype(int)

# %%
train_df.head()
# Out:
#       Id DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 0  14038         35    2.0  47.981560   29.442751            6.0    7.0
# 1  15053         41    3.0  65.683640   40.049541            8.0    7.0
# 2   4765         53    2.0  44.947952   29.197611            0.0    8.0
# 3   5809         58    2.0  53.352982   52.731510            9.0    8.0
# 4  10783         99    1.0  39.649193   23.776169            7.0   11.0
#
#    HouseFloor  HouseYear  Ecology_1  ...  Shops_1          Price  Ecology_2_A  \
# 0         9.0       1969   0.089040  ...       11  184966.937500            0
# 1         9.0       1978   0.000070  ...       16  300009.437500            0
# 2        12.0       1968   0.049637  ...        3  220925.906250            0
# 3        17.0       1977   0.437885  ...        5  175616.234375            0
# 4        12.0       1976   0.012339  ...        4  150226.531250            0
#
#    Ecology_2_B  Ecology_3_A  Ecology_3_B  Shops_2_A  Shops_2_B  DistrictSize  \
# 0            1            0            1          0          1            22
# 1            1            0            1          0          1            87
# 2            1            0            1          0          1           174
# 3            1            0            1          0          1           179
# 4            1            0            1          0          1            97
#
#    IsDistrictLarge
# 0                0
# 1                0
# 2                1
# 3                1
# 4                0
#
# [5 rows x 25 columns]
